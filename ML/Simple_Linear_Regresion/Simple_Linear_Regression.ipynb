# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/student_data.csv')

# %%
df.head()
# Out:
#    CGPA  Package
# 0  6.87    13.06
# 1  9.75    19.73
# 2  8.66    17.61
# 3  7.99    15.27
# 4  5.78    13.43

# %%
plt.scatter(df['CGPA'],df['Package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      13.06
# 1      19.73
# 2      17.61
# 3      15.27
# 4      13.43
#        ...
# 195    12.09
# 196    16.54
# 197    18.77
# 198    19.19
# 199    19.28
# Name: Package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      CGPA
# 112  9.65
# 29   5.23
# 182  9.62
# 199  8.90
# 193  8.17
# 85   6.63
# 10   5.10
# 54   7.99
# 115  9.36
# 35   9.04
# 12   9.16
# 92   8.80
# 13   6.06
# 126  9.09
# 174  8.23
# 2    8.66
# 44   6.29
# 3    7.99
# 113  9.04
# 14   5.91
# 23   6.83
# 25   8.93
# 6    5.29
# 134  9.71
# 165  9.18
# 173  6.13
# 45   8.31
# 65   7.71
# 48   7.73
# 122  6.59
# 178  9.68
# 64   6.40
# 9    8.54
# 57   5.98
# 78   6.79
# 71   5.99
# 128  5.03
# 176  8.45
# 131  6.11
# 53   9.47

# %%
y_test
# Out:
# 112    19.05
# 29      9.60
# 182    20.22
# 199    19.28
# 193    16.57
# 85     13.45
# 10     11.36
# 54     16.50
# 115    17.29
# 35     18.01
# 12     19.28
# 92     16.40
# 13     12.53
# 126    18.25
# 174    17.62
# 2      17.61
# 44     11.70
# 3      15.27
# 113    16.83
# 14     12.64
# 23     14.49
# 25     19.31
# 6       9.39
# 134    19.27
# 165    18.05
# 173    11.05
# 45     16.77
# 65     15.18
# 48     15.82
# 122    12.20
# 178    19.35
# 64     12.03
# 9      17.87
# 57     15.81
# 78     12.85
# 71     10.37
# 128    10.17
# 176    17.52
# 131    10.98
# 53     18.00
# Name: Package, dtype: float64

# %%
cgpa_input = float(input("Enter Your CGPA: "))
predicted_package = lr.predict(pd.DataFrame([[cgpa_input]],columns=['CGPA']))
print(f"Predicted Package for {cgpa_input} is {predicted_package[0]:.2f}")
# Out:
# Enter Your CGPA: 6.11
# Predicted Package for 6.11 is 12.34

# %%
plt.scatter(df['CGPA'],df['Package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([17.20815499])

# %%
m * 9.5 + b
# Out:
# array([4.40443183])

# %%
m * 100 + b
# Out:
# array([54.89908542])
